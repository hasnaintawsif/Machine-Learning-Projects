# %%
import pandas as pd
df = pd.read_csv('C:/Users/Admin/Downloads/Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='airconditioning', y='price', hue='guestroom', data=df)
# Out:
# <Axes: xlabel='airconditioning', ylabel='price'>

# %% [markdown]
# How does furnishingstatus influence price across different stories?

# %%
sns.catplot(x='stories', y='price', hue='furnishingstatus', kind='box', data=df)

# %% [markdown]
# How does area influence price for different levels of parking?

# %%
sns.lmplot(x='area', y='price', hue='parking', data=df, aspect=1.5)

# %% [markdown]
# Combined effect of bedrooms and bathrooms on price

# %%
sns.catplot(x='bedrooms', y='price', hue='bathrooms', kind='box', data=df, aspect=1.5)

# %% [markdown]
# Let's see if the Luxury Packs affect the price

# %% [markdown]
# Does mainroad access + prefarea (preferred area) combo affect price?

# %%
sns.catplot(x='mainroad', y='price', hue='prefarea', kind='box', data=df, aspect=1.5)

# %% [markdown]
# Price by furnishingstatus in homes with vs. without guestroom

# %%
sns.catplot(x='furnishingstatus', y='price', hue='guestroom', kind='box', data=df, aspect=1.5)
